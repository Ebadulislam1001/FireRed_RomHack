# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('moves_info.csv')
df = df.sort_values(['secondaryEffect', 'basePower', 'type']).reset_index(drop=True)
move_map = df[['serial', 'oldName', 'newName']]
move_effects = df[['newName', 'type', 'secondaryEffect', 'effectChance', 'basePower', 'accuracy', 'PP', 'priority', 'target', 'description']]
move_flags = df[['newName', 'makesContact', 'protectAffected', 'magicCoatAffected', 'snatchAffected', 'mirrorMoveAffected', 'kingsRockAffected']]
print(f"{len(df)} rows")
# Out:
# 354 rows

# %% [markdown]
# ## Repeat

# %%
start, stop = 300, 360
move_effects[start:stop]
# Out:
#           newName      type           secondaryEffect  effectChance  \
# 300  CRYSTAL BEAM      ROCK   SPECIAL_ATTACK_DOWN_HIT            20
# 301        GROWTH    NORMAL         SPECIAL_ATTACK_UP             0
# 302     CHARGE UP  ELECTRIC       SPECIAL_ATTACK_UP_2             0
# 303          LEER    NORMAL      SPECIAL_DEFENSE_DOWN             0
# 304   METAL SOUND     STEEL    SPECIAL_DEFENSE_DOWN_2             0
# 305        CRUNCH      DARK  SPECIAL_DEFENSE_DOWN_HIT            20
# 306   AZURE DRIVE    DRAGON  SPECIAL_DEFENSE_DOWN_HIT            20
# 307   ENERGY BALL     GRASS  SPECIAL_DEFENSE_DOWN_HIT            20
# 308       PSYCHIC   PSYCHIC  SPECIAL_DEFENSE_DOWN_HIT            20
# 309    ACID ARMOR    POISON        SPECIAL_DEFENSE_UP             0
# 310       AMNESIA   PSYCHIC      SPECIAL_DEFENSE_UP_2             0
# 311    SPIDER WEB       BUG                SPEED_DOWN             0
# 312   STRING SHOT       BUG              SPEED_DOWN_2             0
# ...

# %%
move_flags[start:stop]
# Out:
#           newName  makesContact  protectAffected  magicCoatAffected  \
# 300  CRYSTAL BEAM             0                1                  0
# 301        GROWTH             0                0                  0
# 302     CHARGE UP             0                0                  0
# 303          LEER             0                1                  1
# 304   METAL SOUND             0                1                  1
# 305        CRUNCH             1                1                  0
# 306   AZURE DRIVE             1                1                  0
# 307   ENERGY BALL             0                1                  0
# 308       PSYCHIC             0                1                  0
# 309    ACID ARMOR             0                0                  0
# 310       AMNESIA             0                0                  0
# 311    SPIDER WEB             0                1                  1
# 312   STRING SHOT             0                1                  1
# ...
